# %%
import pandas as pd
data=pd.read_excel("fitness.xlsx")
print(data.head())
# Out:
#         Date      Time  Step Count  Distance  Energy Burned  Flights Climbed  \
# 0 2023-03-21  16:01:23          46   0.02543         14.620                3
# 1 2023-03-21  16:18:37         645   0.40041         14.722                3
# 2 2023-03-21  16:31:38          14   0.00996         14.603                4
# 3 2023-03-21  16:45:37          13   0.00901         14.811                3
# 4 2023-03-21  17:10:30          17   0.00904         15.153                3
#
#    Walking Double Support Percentage  Walking Speed
# 0                              0.304          3.060
# 1                              0.309          3.852
# 2                              0.278          3.996
# 3                              0.278          5.040
# 4                              0.281          5.184

# %%
data.isnull()
# Out:
#       Date   Time  Step Count  Distance  Energy Burned  Flights Climbed  \
# 0    False  False       False     False          False            False
# 1    False  False       False     False          False            False
# 2    False  False       False     False          False            False
# 3    False  False       False     False          False            False
# 4    False  False       False     False          False            False
# ..     ...    ...         ...       ...            ...              ...
# 144  False  False       False     False          False            False
# 145  False  False       False     False          False            False
# 146  False  False       False     False          False            False
# 147  False  False       False     False          False            False
# 148  False  False       False     False          False            False
#
#      Walking Double Support Percentage  Walking Speed
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("fitness.xlsx")
df=pd.DataFrame(data)
print(df)
plt.scatter(df["Flights Climbed"],df["Step Count"])
plt.xlabel("Flights Climbed",fontsize=20)
plt.ylabel("Step Count",fontsize=20)
plt.show()
# Out:
#           Date      Time  Step Count  Distance  Energy Burned  \
# 0   2023-03-21  16:01:23          46   0.02543         14.620
# 1   2023-03-21  16:18:37         645   0.40041         14.722
# 2   2023-03-21  16:31:38          14   0.00996         14.603
# 3   2023-03-21  16:45:37          13   0.00901         14.811
# 4   2023-03-21  17:10:30          17   0.00904         15.153
# ..         ...       ...         ...       ...            ...
# 144 2023-04-01  16:04:23          87   0.05872         13.162
# 145 2023-04-01  16:33:18          37   0.02039          4.135
# 146 2023-04-01  16:49:49         969   0.65379         31.416
# 147 2023-04-01  17:09:06         640   0.42356         13.250
# 148 2023-04-01  17:47:07        1081   0.67835         14.131
#
#      Flights Climbed  Walking Double Support Percentage  Walking Speed
# 0                  3                              0.304          3.060
# 1                  3                              0.309          3.852
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("fitness.xlsx")
df=pd.DataFrame(data)
print(df)
plt.bar(df["Flights Climbed"],df["Step Count"])
plt.xlabel("Flights Climbed",fontsize=20)
plt.ylabel("Step Count",fontsize=20)
plt.show()
# Out:
#           Date      Time  Step Count  Distance  Energy Burned  \
# 0   2023-03-21  16:01:23          46   0.02543         14.620
# 1   2023-03-21  16:18:37         645   0.40041         14.722
# 2   2023-03-21  16:31:38          14   0.00996         14.603
# 3   2023-03-21  16:45:37          13   0.00901         14.811
# 4   2023-03-21  17:10:30          17   0.00904         15.153
# ..         ...       ...         ...       ...            ...
# 144 2023-04-01  16:04:23          87   0.05872         13.162
# 145 2023-04-01  16:33:18          37   0.02039          4.135
# 146 2023-04-01  16:49:49         969   0.65379         31.416
# 147 2023-04-01  17:09:06         640   0.42356         13.250
# 148 2023-04-01  17:47:07        1081   0.67835         14.131
#
#      Flights Climbed  Walking Double Support Percentage  Walking Speed
# 0                  3                              0.304          3.060
# 1                  3                              0.309          3.852
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel("fitness.xlsx")
df=pd.DataFrame(data)
print(df)
grouped_by=df.groupby("Step Count")["Distance"].sum()
print(grouped_by)
plt.plot(grouped_by.index,grouped_by.values)
plt.xlabel("Time",fontsize=20)
plt.ylabel("Distance",fontsize=20)
plt.show()
# Out:
#           Date      Time  Step Count  Distance  Energy Burned  \
# 0   2023-03-21  16:01:23          46   0.02543         14.620
# 1   2023-03-21  16:18:37         645   0.40041         14.722
# 2   2023-03-21  16:31:38          14   0.00996         14.603
# 3   2023-03-21  16:45:37          13   0.00901         14.811
# 4   2023-03-21  17:10:30          17   0.00904         15.153
# ..         ...       ...         ...       ...            ...
# 144 2023-04-01  16:04:23          87   0.05872         13.162
# 145 2023-04-01  16:33:18          37   0.02039          4.135
# 146 2023-04-01  16:49:49         969   0.65379         31.416
# 147 2023-04-01  17:09:06         640   0.42356         13.250
# 148 2023-04-01  17:47:07        1081   0.67835         14.131
#
#      Flights Climbed  Walking Double Support Percentage  Walking Speed
# 0                  3                              0.304          3.060
# 1                  3                              0.309          3.852
# ...
